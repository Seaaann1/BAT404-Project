# %% [markdown]
# <a href="https://colab.research.google.com/github/Seaaann1/BAT404-Project/blob/main/Chart4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

labels = ['267 Million']
share = [70] 
plt.style.use('ggplot')
plt.pie(x=share, labels=labels, startangle=90) 
plt.axis('equal') 
circle = plt.Circle(xy=(0,0), radius=.75, facecolor='white')
plt.pie(marks, colors=['#43BFC7','#008B8B'], startangle=90)
plt.gca().add_artist(circle)
plt.show()
